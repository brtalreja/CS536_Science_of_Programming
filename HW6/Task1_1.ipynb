# %%
Gas_val = int(input("How many units of gas do you have?\n"))
Batt_val = int(input("How many units of battery do you have?\n"))

miles = 0
while Gas_val > 1 or Batt_val > 0:
    print("")
    if Batt_val > 0:
        Batt_val = Batt_val - 1
        print("IF BLOCK")
        print(f"Updated value of Miles: {miles}, Units of Gas: {Gas_val}, Units of Battery: {Batt_val}")
    else:
        Gas_val = Gas_val - 2
        Batt_val = Batt_val + 1
        print("ELSE BLOCK")
        print(f"Updated value of Miles: {miles}, Units of Gas: {Gas_val}, Units of Battery: {Batt_val}")
    miles = miles + 1

print(f"Final value of Miles: {miles}, Units of Gas: {Gas_val}, Units of Battery: {Batt_val}")
# Out:
# How many units of gas do you have?
# 10
# How many units of battery do you have?
# 10
#
# IF BLOCK
# Updated value of Miles: 0, Units of Gas: 10, Units of Battery: 9
#
# IF BLOCK
# Updated value of Miles: 1, Units of Gas: 10, Units of Battery: 8
#
# IF BLOCK
# Updated value of Miles: 2, Units of Gas: 10, Units of Battery: 7
#
# IF BLOCK
# Updated value of Miles: 3, Units of Gas: 10, Units of Battery: 6
#
# IF BLOCK
# Updated value of Miles: 4, Units of Gas: 10, Units of Battery: 5
#
# IF BLOCK
# Updated value of Miles: 5, Units of Gas: 10, Units of Battery: 4
#
# IF BLOCK
# Updated value of Miles: 6, Units of Gas: 10, Units of Battery: 3
#
# IF BLOCK
# Updated value of Miles: 7, Units of Gas: 10, Units of Battery: 2
#
# IF BLOCK
# Updated value of Miles: 8, Units of Gas: 10, Units of Battery: 1
#
# IF BLOCK
# Updated value of Miles: 9, Units of Gas: 10, Units of Battery: 0
#
# ELSE BLOCK
# Updated value of Miles: 10, Units of Gas: 8, Units of Battery: 1
#
# IF BLOCK
# Updated value of Miles: 11, Units of Gas: 8, Units of Battery: 0
#
# ELSE BLOCK
# Updated value of Miles: 12, Units of Gas: 6, Units of Battery: 1
#
# IF BLOCK
# Updated value of Miles: 13, Units of Gas: 6, Units of Battery: 0
#
# ELSE BLOCK
# Updated value of Miles: 14, Units of Gas: 4, Units of Battery: 1
#
# IF BLOCK
# Updated value of Miles: 15, Units of Gas: 4, Units of Battery: 0
#
# ELSE BLOCK
# Updated value of Miles: 16, Units of Gas: 2, Units of Battery: 1
#
# IF BLOCK
# Updated value of Miles: 17, Units of Gas: 2, Units of Battery: 0
#
# ELSE BLOCK
# Updated value of Miles: 18, Units of Gas: 0, Units of Battery: 1
#
# IF BLOCK
# Updated value of Miles: 19, Units of Gas: 0, Units of Battery: 0
# Final value of Miles: 20, Units of Gas: 0, Units of Battery: 0
